# %%
# !pip install seaborn

# %%
import seaborn as sns

# %%
#basic plotting with seaborn
tips=sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
#create a scatter plot
import matplotlib.pyplot as plt
sns.scatterplot(x='total_bill',y='tip',data=tips)
plt.totle("Scatter plot for total bill vs tip")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 4
#       2 import matplotlib.pyplot as plt
#       3 sns.scatterplot(x='total_bill',y='tip',data=tips)
# ----> 4 plt.totle("Scatter plot for total bill vs tip")
#       5 plt.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'totle'

# %%
sns.lineplot(x='size',y='total_bill',data=tips)
plt.title("lineplot for total_bill vs size")
plt.show()

# %%
sns.barplot(x='day',y='total_bill',data=tips)
plt.title("barplot for day vs total bill")
plt.show()

# %%
sns.boxplot(x='day',y='total_bill',data=tips)
plt.title("boxplot")
plt.show()

# %%
sns.violinplot(x='day',y='total_bill',data=tips)
plt.title("violin plot")
plt.show()

# %%
sns.histplot(tips["total_bill"],bins=10,kde=True)
plt.show()

# %%
sns.histplot(tips["total_bill"],bins=10,kde=False)
plt.show()

# %%
sns.kdeplot(tips["total_bill"],shade=True)
# Out:
# C:\Users\manas\AppData\Local\Temp\ipykernel_137024\1388039876.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(tips["total_bill"],shade=True)
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.pairplot(tips)

# %%
corr=tips[["total_bill","tip","size"]].corr()
corr
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(corr,annot=True,cmap="coolwarm")
# Out:
# <Axes: >

# %%
import pandas as pd
student_df=pd.read_csv("large_student_data.csv")
student_df.head()
# Out:
#    Student_ID    Name  Age          Course  Marks  Attendance_Percentage  \
# 0        1001   Priya   22  Cyber Security     94                     65
# 1        1002  Manasi   23             CSE     67                     60
# 2        1003    Riya   22             ECE     62                     86
# 3        1004  Vihaan   23              DS     92                     82
# 4        1005  Vivaan   20             CSE     85                     70
#
#       City  Semester  CGPA
# 0  Palghar         1  5.19
# 1    Delhi         5  9.25
# 2   Nagpur         7  8.30
# 3    Thane         4  6.53
# 4  Palghar         6  5.92

# %%
#marks city
sns.barplot(x="City",y="Marks",data=student_df,estimator=sum)
# Out:
# <Axes: xlabel='City', ylabel='Marks'>
