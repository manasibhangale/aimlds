# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.datasets import make_classification
X,y=make_classification(n_samples=1000,n_classes=2,n_features=2,n_redundant=0,n_clusters_per_class=1)

# %%
X
# Out:
# array([[-0.43452538,  0.25257038],
#        [-0.13987169,  2.12216206],
#        [ 1.21314647,  0.95316828],
#        ...,
#        [ 0.57786526,  1.5098193 ],
#        [ 0.69622297,  1.1849864 ],
#        [ 1.54397747,  0.46282371]], shape=(1000, 2))

# %%
pd.DataFrame(X)
# Out:
#             0         1
# 0   -0.434525  0.252570
# 1   -0.139872  2.122162
# 2    1.213146  0.953168
# 3    0.056657  2.088048
# 4    0.652664  1.193800
# ..        ...       ...
# 995  0.435087  1.450458
# 996 -0.267407  0.207543
# 997  0.577865  1.509819
# 998  0.696223  1.184986
# 999  1.543977  0.462824
#
# [1000 rows x 2 columns]

# %%
pd.DataFrame(X)[0]
# Out:
# 0     -0.434525
# 1     -0.139872
# 2      1.213146
# 3      0.056657
# 4      0.652664
#          ...
# 995    0.435087
# 996   -0.267407
# 997    0.577865
# 998    0.696223
# 999    1.543977
# Name: 0, Length: 1000, dtype: float64

# %%
pd.DataFrame(X)[1]
# Out:
# 0      0.252570
# 1      2.122162
# 2      0.953168
# 3      2.088048
# 4      1.193800
#          ...
# 995    1.450458
# 996    0.207543
# 997    1.509819
# 998    1.184986
# 999    0.462824
# Name: 1, Length: 1000, dtype: float64

# %%
sns.scatterplot(
    x=pd.DataFrame(X)[0],
    y=pd.DataFrame(X)[1],
    hue=y
)
plt.show()

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=10)

# %%
from sklearn.svm import SVC
svc=SVC(kernel='linear')
svc.fit(X_train,y_train)
# Out:
# SVC(kernel='linear')

# %%
y_pred=svc.predict(X_test)

# %%
from sklearn.metrics import classification_report,confusion_matrix
print(classification_report(y_test,y_pred))
print(confusion_matrix(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00       140
#            1       1.00      0.99      1.00       110
#
#     accuracy                           1.00       250
#    macro avg       1.00      1.00      1.00       250
# weighted avg       1.00      1.00      1.00       250
#
# [[140   0]
#  [  1 109]]

# %%
rbf=SVC(kernel='rbf')

# %%
rbf.fit(X_train,y_train)
# Out:
# SVC()

# %%
y_pred_rbf=svc.predict(X_test)

# %%
from sklearn.metrics import classification_report,confusion_matrix
print(classification_report(y_test,y_pred_rbf))
print(confusion_matrix(y_test,y_pred_rbf))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00       140
#            1       1.00      0.99      1.00       110
#
#     accuracy                           1.00       250
#    macro avg       1.00      1.00      1.00       250
# weighted avg       1.00      1.00      1.00       250
#
# [[140   0]
#  [  1 109]]

# %%
from sklearn.svm import SVC

svc = SVC(kernel='sigmoid')

svc.fit(X_train, y_train)

y_pred_sigmoid = svc.predict(X_test)

# %%
from sklearn.metrics import classification_report,confusion_matrix
print(classification_report(y_test,y_pred_sigmoid))
print(confusion_matrix(y_test,y_pred_sigmoid))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.94      0.91       140
#            1       0.92      0.83      0.87       110
#
#     accuracy                           0.89       250
#    macro avg       0.90      0.89      0.89       250
# weighted avg       0.89      0.89      0.89       250
#
# [[132   8]
#  [ 19  91]]

# %%
from sklearn.model_selection import GridSearchCV, StratifiedKFold
from sklearn.svm import SVC

svc = SVC(kernel='sigmoid')

params = {
    'C': [0.01, 0.1, 1, 10, 100],
    'gamma': ['scale', 'auto', 0.001, 0.01, 0.1, 1],
    'coef0': [0, 0.1, 0.5, 1, 2, 5]
}

cv = StratifiedKFold(
    n_splits=5,
    shuffle=True,
    random_state=42
)

grid = GridSearchCV(
    estimator=svc,
    param_grid=params,
    cv=cv,
    scoring='accuracy',
    n_jobs=-1
)

grid.fit(X_train, y_train)

print("Best Parameters:", grid.best_params_)
print("Best CV Score:", grid.best_score_)
# Out:
# Best Parameters: {'C': 0.1, 'coef0': 0, 'gamma': 0.1}
# Best CV Score: 0.9959999999999999

# %%
best_svc = grid.best_estimator_

y_pred = best_svc.predict(X_test)

print(classification_report(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00       140
#            1       1.00      0.99      1.00       110
#
#     accuracy                           1.00       250
#    macro avg       1.00      1.00      1.00       250
# weighted avg       1.00      1.00      1.00       250
#
# [[140   0]
#  [  1 109]]

# %%
from sklearn.metrics import roc_auc_score

y_prob = best_svc.decision_function(X_test)

print("ROC AUC:", roc_auc_score(y_test, y_prob))
# Out:
# ROC AUC: 0.995909090909091
